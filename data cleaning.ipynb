# %%
import string
import pandas as pd
import numpy as np
import nltk
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

result=string.punctuation
print(result)



df=pd.read_excel(r'G:\TROP ICSU INTERNSHIP\tweets data.xlsx',engine='openpyxl')
df.head()
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
##remove punctuations
def remove_punctuation(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    return s
df['no_punctuations'] = df['tweet'].apply(remove_punctuation)
df.head()
#########
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence                                    no_punctuations
# 0                1.0000  Global warming report urges governments to act...
# 1                1.0000  Fighting poverty and global warming in Africa ...
# 2                0.8786  Carbon offsets How a Vatican forest failed to ...
# 3                1.0000  Carbon offsets How a Vatican forest failed to ...
# 4                0.8087  URUGUAY Tools Needed for Those Most Vulnerable...

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer(r'\w+')
df['after_tokenizer']=df['no_punctuations'].apply(lambda x: tokenizer.tokenize(x.lower()))
df.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence                                    no_punctuations  \
# 0                1.0000  Global warming report urges governments to act...
# 1                1.0000  Fighting poverty and global warming in Africa ...
# 2                0.8786  Carbon offsets How a Vatican forest failed to ...
# 3                1.0000  Carbon offsets How a Vatican forest failed to ...
# 4                0.8087  URUGUAY Tools Needed for Those Most Vulnerable...
#
#                                      after_tokenizer
# 0  [global, warming, report, urges, governments, ...
# 1  [fighting, poverty, and, global, warming, in, ...
# 2  [carbon, offsets, how, a, vatican, forest, fai...
# 3  [carbon, offsets, how, a, vatican, forest, fai...
# 4  [uruguay, tools, needed, for, those, most, vul...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

def remove_stopwords(text):
    words=[w for w in text if w not in stopwords.words('english')]
    return words
df['stopword']=df['after_tokenizer'].apply(lambda x:remove_stopwords(x))
df.head()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Naveen
# [nltk_data]     Anupoju\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence                                    no_punctuations  \
# 0                1.0000  Global warming report urges governments to act...
# 1                1.0000  Fighting poverty and global warming in Africa ...
# 2                0.8786  Carbon offsets How a Vatican forest failed to ...
# 3                1.0000  Carbon offsets How a Vatican forest failed to ...
# 4                0.8087  URUGUAY Tools Needed for Those Most Vulnerable...
#
#                                      after_tokenizer  \
# 0  [global, warming, report, urges, governments, ...
# 1  [fighting, poverty, and, global, warming, in, ...
# 2  [carbon, offsets, how, a, vatican, forest, fai...
# 3  [carbon, offsets, how, a, vatican, forest, fai...
# 4  [uruguay, tools, needed, for, those, most, vul...
#
#                                             stopword
# 0  [global, warming, report, urges, governments, ...
# 1  [fighting, poverty, global, warming, africa, l...
# 2  [carbon, offsets, vatican, forest, failed, red...
# 3  [carbon, offsets, vatican, forest, failed, red...
# 4  [uruguay, tools, needed, vulnerable, climate, ...

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer=WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text=[lemmatizer.lemmatize(i) for i in text]
    return lem_text
df['lemmatize']=df['stopword'].apply(lambda x:word_lemmatizer(x))
df.head()
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Naveen
# [nltk_data]     Anupoju\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0    [global, warming, report, urge, government, ac...
# 1    [fighting, poverty, global, warming, africa, l...
# 2    [carbon, offset, vatican, forest, failed, redu...
# 3    [carbon, offset, vatican, forest, failed, redu...
# 4    [uruguay, tool, needed, vulnerable, climate, c...
# Name: lemmatize, dtype: object

# %%
from nltk.stem.porter import PorterStemmer
stemmer =PorterStemmer()
def word_stemmer(text):
    stem_text=" ".join([stemmer.stem(i) for i in text])
    return stem_text
df['stem']=df['lemmatize'].apply(lambda x:word_stemmer(x))
df.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence                                    no_punctuations  \
# 0                1.0000  Global warming report urges governments to act...
# 1                1.0000  Fighting poverty and global warming in Africa ...
# 2                0.8786  Carbon offsets How a Vatican forest failed to ...
# 3                1.0000  Carbon offsets How a Vatican forest failed to ...
# 4                0.8087  URUGUAY Tools Needed for Those Most Vulnerable...
#
#                                      after_tokenizer  \
# 0  [global, warming, report, urges, governments, ...
# 1  [fighting, poverty, and, global, warming, in, ...
# 2  [carbon, offsets, how, a, vatican, forest, fai...
# 3  [carbon, offsets, how, a, vatican, forest, fai...
# 4  [uruguay, tools, needed, for, those, most, vul...
#
#                                             stopword  \
# 0  [global, warming, report, urges, governments, ...
# 1  [fighting, poverty, global, warming, africa, l...
# 2  [carbon, offsets, vatican, forest, failed, red...
# 3  [carbon, offsets, vatican, forest, failed, red...
# 4  [uruguay, tools, needed, vulnerable, climate, ...
#
#                                            lemmatize  \
# 0  [global, warming, report, urge, government, ac...
# 1  [fighting, poverty, global, warming, africa, l...
# 2  [carbon, offset, vatican, forest, failed, redu...
# 3  [carbon, offset, vatican, forest, failed, redu...
# 4  [uruguay, tool, needed, vulnerable, climate, c...
#
#                                                 stem
# 0  global warm report urg govern actbrussel belgi...
# 1              fight poverti global warm africa link
# 2  carbon offset vatican forest fail reduc global...
# 3  carbon offset vatican forest fail reduc global...
# 4         uruguay tool need vulner climat chang link
